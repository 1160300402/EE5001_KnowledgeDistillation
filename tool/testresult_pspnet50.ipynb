# %%
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/pspnet1")

# %%
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/pspnet1')
import  os
print(os.getcwd())
# Out:
# /content/drive/MyDrive/Colab Notebooks/pspnet1

# %%
! python tool/test.py
# Out:
# [2022-01-17 10:26:16,908 INFO test.py line 74 281] arch: psp
# aux_weight: 0.4
# base_lr: 0.01
# base_size: 2048
# batch_size: 2
# batch_size_val: 8
# classes: 19
# colors_path: ./data/cityscapes/cityscapes_colors.txt
# data_root: ./dataset/cityscapes
# dist_backend: nccl
# dist_url: tcp://127.0.0.1:6789
# epochs: 2
# evaluate: False
# has_prediction: False
# ignore_label: 255
# index_start: 0
# index_step: 0
# layers: 50
# manual_seed: None
# model_path: ./exp/cityscapes/pspnet50/model/train_epoch_200.pth
# momentum: 0.9
# multiprocessing_distributed: True
# names_path: ./data/cityscapes/cityscapes_names.txt
# power: 0.9
# print_freq: 10
# rank: 0
# resume: False
# rotate_max: 10
# rotate_min: -10
# save_folder: ./exp/cityscapes/pspnet50/result/epoch_200/val/ss
# save_freq: 1
# save_path: ../exp/cityscapes/pspnet50/model
# scale_max: 2.0
# scale_min: 0.5
# scales: [1.0]
# split: val
# start_epoch: 0
# sync_bn: False
# test_gpu: [0]
# test_h: 713
# ...

# %%
! python tool/test_colab_pspnet101.py
# Out:
# [2022-01-27 05:24:26,949 INFO test_colab_pspnet101.py line 74 282] arch: psp
# aux_weight: 0.4
# base_lr: 0.01
# base_size: 2048
# batch_size: 16
# batch_size_val: 8
# classes: 19
# colors_path: data/cityscapes/cityscapes_colors.txt
# data_root: ./dataset/cityscapes
# dist_backend: nccl
# dist_url: tcp://127.0.0.1:6789
# epochs: 200
# evaluate: False
# has_prediction: False
# ignore_label: 255
# index_start: 0
# index_step: 0
# layers: 101
# manual_seed: None
# model_path: exp/cityscapes/pspnet101/model/train_epoch_200.pth
# momentum: 0.9
# multiprocessing_distributed: True
# names_path: data/cityscapes/cityscapes_names.txt
# power: 0.9
# print_freq: 10
# rank: 0
# resume: None
# rotate_max: 10
# rotate_min: -10
# save_folder: exp/cityscapes/pspnet101/result/epoch_200/val/ss
# save_freq: 1
# save_path: exp/cityscapes/pspnet101/model
# scale_max: 2.0
# scale_min: 0.5
# scales: [1.0]
# split: val
# start_epoch: 0
# sync_bn: True
# test_gpu: [0]
# test_h: 713
# ...
